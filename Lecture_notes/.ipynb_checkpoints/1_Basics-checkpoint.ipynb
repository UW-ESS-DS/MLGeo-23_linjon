# %% [markdown]
# # 1. Basics
#
# Jupyter notebooks, Markdown, Git, CLI, environments, basic syntax, etc.

# %% [markdown]
# ## Jupyter
#
# A Jupyter notebook allows you to merge text (written in Markdown, see below), images, HTML, LateX, code, and code output. It is a JSON file. The notebook is composed of cells that can be either code or text.
#
# #### Jupyter Lab
#
# Jupyter Lab is an expanded version of the browser interface that includes notebooks, terminal, files (CSV, JSON etc), images, and other.
#
# #### Jupyter Hub
# Is a Jupyter Lab launched by a given hardware/computer. Users may see where the computer is located in the browser address. The user may not know the type of hardware used. One exception is the selection of types of instances in public clouds.
#
# ### Basic Markdown commands
#
# #### Headings and text formatting
#
#     # Heading level 1
#     ## Heading level 2
#     ### Heading level 3
#
# Paragraphs: Leave a blank line
#
# **This is my bold text**
#
# *This is my italic text*
#
# ***This is my bold, italic text***
#
# ~~Scratched Text~~
#
# Markdown supports HTML text. For instance, one can underline a text
#
# <\u>text</\u>
#
# Line break: use <br>
#
# #### Lists
#
# Numbered:
# 1. First item
# 2. Second item
# 3. Third item
# 4. Fourth item
#
# Unordered:
# - First item
# - Second item
# - Third item
# - Fourth item
# * Fifth item
# * Sixth item
#
# #### HTML, LaTeX
#
# Insert URLs: `[Github](https://github.com/UW-ESS-DS/ESS490-590-Autmn22)`
#
# Insert images:
#
#  `<img src="/img.png" width="200"/>`
#
# LaTeX: $$\sqrt{x}$$

# %% [markdown]
# ## Environments
#
# Computing environments manage the correct versions of the python interpreter and libraries used in a project, so you need to make an environment.yml file for your project, allowing anyone to open the project and work on it with the right versions of everything.
#
# An environment is a version of python + some packages with specific versions.
#
# Conda (anaconda, miniconda) lets you manage your environment. That's why you have them.
#
# #### Basic conda commands
#
#     conda info
#
# to check conda version to make sure its installed.
#
#     conda env list
#
# to list out available environments (the starred * environment is the current activate environment).
#
#     conda env create --file environment.yml
#
# to create conda environment from environment file.
#
#     conda env remove --yes --name myenv
#
# to delete the conda environment.
#
#     conda activate myenv
#
# to activate a conda enivronment by the env name myenv. Inside the environment, there are other ways to add libraries. Use conda install or pip3 install to add packages that will be automatically saved.
#
#     conda deactivate
#
# to deactivate the current cona environment.
#
# You may need to freeze an environment to ensure that the code you wrote will run on the exact right version:
#
#     (venv) $ pip3 freeze > requirements.txt
